# %%
import gymnasium as gym
import gymnasium_robotics as gymr
from stable_baselines3 import A2C, SAC, PPO, TD3, DDPG, HerReplayBuffer
from stable_baselines3.common.evaluation import evaluate_policy
from sb3_contrib import TQC
from stable_baselines3.common.noise import NormalActionNoise
from sb3_contrib.common.wrappers.time_feature import TimeFeatureWrapper
import psutil
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback
import numpy as np
import multiprocessing

# %%
num_cpu_cores = multiprocessing.cpu_count()
num_cpu_cores
# Out:
# 26

# %%
env = gym.make('FetchPickAndPlace-v2')

# %% [markdown]
# ## n_actions

# %%
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

# %%
model = TQC(
    'MultiInputPolicy',
    env,
    replay_buffer_class=HerReplayBuffer,
    replay_buffer_kwargs=dict(
        n_sampled_goal=4,
        goal_selection_strategy="future"
    ),
    action_noise=action_noise,
    learning_rate=3e-4,
    batch_size=256,
    buffer_size=1000000,
    learning_starts=10000,
    train_freq=1000,
    gradient_steps=1000,
    verbose=1
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=500000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 838      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 200      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 876      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 400      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 889      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 600      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -46.9    |
# |    success_rate    | 0.0625   |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 899      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 800      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 894      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.9    |
# |    success_rate    | 0.0417   |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 897      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.2    |
# |    success_rate    | 0.0357   |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 898      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.9    |
# |    success_rate    | 0.0312   |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 900      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.2    |
# |    success_rate    | 0.0278   |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 901      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.4    |
# |    success_rate    | 0.025    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 901      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.0227   |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 901      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.0417   |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 901      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.8    |
# |    success_rate    | 0.0385   |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 903      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.9    |
# |    success_rate    | 0.0357   |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 903      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.0333   |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 903      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 3000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.2    |
# |    success_rate    | 0.0312   |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 905      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 3200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.0441   |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 906      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 3400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.7    |
# |    success_rate    | 0.0417   |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 904      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 3600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.8    |
# |    success_rate    | 0.0395   |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 905      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 3800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.3    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 906      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 4000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.4    |
# |    success_rate    | 0.0476   |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 906      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 4200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.0455   |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 906      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 4400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.7    |
# |    success_rate    | 0.0435   |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 905      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 4600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.8    |
# |    success_rate    | 0.0417   |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 906      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 4800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.8    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 906      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 5000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.8    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 907      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 5200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.3    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 908      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 5400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.3    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 909      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 5600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.8    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 910      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 5800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.3    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 910      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 6000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.3    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 910      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 6200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -46.8    |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 910      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 6400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47      |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 911      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 6600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47      |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 912      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 6800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47      |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 911      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 7000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47      |
# |    success_rate    | 0.06     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 911      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 7200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 912      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 7400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 910      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 7600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 909      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 7800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 909      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 8000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 909      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 8200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 909      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 8400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 910      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 8600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 909      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 8800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 909      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 9000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 908      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 9200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.2    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 908      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 9400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.2    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 908      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 9600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.2    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 908      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 9800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.2    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 908      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 10000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.2    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 906      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 10200    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.7    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 903      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 10400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.7    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 900      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 10600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.7    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 898      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 10800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.7    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 896      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 11000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 381      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 11200    |
# | train/             |          |
# |    actor_loss      | -7.73    |
# |    critic_loss     | 0.0747   |
# |    ent_coef        | 0.864    |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 384      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 11400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 387      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 11600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 390      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 11800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 393      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 12000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 254      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 12200    |
# | train/             |          |
# |    actor_loss      | -14      |
# |    critic_loss     | 0.0425   |
# |    ent_coef        | 0.64     |
# |    ent_coef_loss   | -3.03    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 257      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 12400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 260      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 12600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 262      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 12800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 265      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 13000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 196      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 13200    |
# | train/             |          |
# |    actor_loss      | -18.4    |
# |    critic_loss     | 0.0365   |
# |    ent_coef        | 0.474    |
# |    ent_coef_loss   | -5.04    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 198      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 13400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 201      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 13600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 203      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 13800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.6    |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 205      |
# |    time_elapsed    | 68       |
# |    total_timesteps | 14000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.1    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 164      |
# |    time_elapsed    | 86       |
# |    total_timesteps | 14200    |
# | train/             |          |
# |    actor_loss      | -21.1    |
# |    critic_loss     | 0.0317   |
# |    ent_coef        | 0.352    |
# |    ent_coef_loss   | -7.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 166      |
# |    time_elapsed    | 86       |
# |    total_timesteps | 14400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 168      |
# |    time_elapsed    | 86       |
# |    total_timesteps | 14600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 169      |
# |    time_elapsed    | 87       |
# |    total_timesteps | 14800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 171      |
# |    time_elapsed    | 87       |
# |    total_timesteps | 15000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 145      |
# |    time_elapsed    | 104      |
# |    total_timesteps | 15200    |
# | train/             |          |
# |    actor_loss      | -22.5    |
# |    critic_loss     | 0.0289   |
# |    ent_coef        | 0.261    |
# |    ent_coef_loss   | -8.96    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 146      |
# |    time_elapsed    | 105      |
# |    total_timesteps | 15400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 148      |
# |    time_elapsed    | 105      |
# |    total_timesteps | 15600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 149      |
# |    time_elapsed    | 105      |
# |    total_timesteps | 15800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 151      |
# |    time_elapsed    | 105      |
# |    total_timesteps | 16000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 131      |
# |    time_elapsed    | 123      |
# |    total_timesteps | 16200    |
# | train/             |          |
# |    actor_loss      | -23.1    |
# |    critic_loss     | 0.0294   |
# |    ent_coef        | 0.194    |
# |    ent_coef_loss   | -10.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 132      |
# |    time_elapsed    | 123      |
# |    total_timesteps | 16400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 134      |
# |    time_elapsed    | 123      |
# |    total_timesteps | 16600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 135      |
# |    time_elapsed    | 123      |
# |    total_timesteps | 16800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 136      |
# |    time_elapsed    | 124      |
# |    total_timesteps | 17000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 121      |
# |    time_elapsed    | 141      |
# |    total_timesteps | 17200    |
# | train/             |          |
# |    actor_loss      | -23.1    |
# |    critic_loss     | 0.0301   |
# |    ent_coef        | 0.144    |
# |    ent_coef_loss   | -12.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 123      |
# |    time_elapsed    | 141      |
# |    total_timesteps | 17400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 124      |
# |    time_elapsed    | 141      |
# |    total_timesteps | 17600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 125      |
# |    time_elapsed    | 141      |
# |    total_timesteps | 17800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 126      |
# |    time_elapsed    | 142      |
# |    total_timesteps | 18000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 114      |
# |    time_elapsed    | 158      |
# |    total_timesteps | 18200    |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 0.0314   |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | -14.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 115      |
# |    time_elapsed    | 159      |
# |    total_timesteps | 18400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 116      |
# |    time_elapsed    | 159      |
# |    total_timesteps | 18600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 117      |
# |    time_elapsed    | 159      |
# |    total_timesteps | 18800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 118      |
# |    time_elapsed    | 160      |
# |    total_timesteps | 19000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 108      |
# |    time_elapsed    | 176      |
# |    total_timesteps | 19200    |
# | train/             |          |
# |    actor_loss      | -21.8    |
# |    critic_loss     | 0.0333   |
# |    ent_coef        | 0.08     |
# |    ent_coef_loss   | -15.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 109      |
# |    time_elapsed    | 177      |
# |    total_timesteps | 19400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 110      |
# |    time_elapsed    | 177      |
# |    total_timesteps | 19600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 111      |
# |    time_elapsed    | 177      |
# |    total_timesteps | 19800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 112      |
# |    time_elapsed    | 178      |
# |    total_timesteps | 20000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 103      |
# |    time_elapsed    | 195      |
# |    total_timesteps | 20200    |
# | train/             |          |
# |    actor_loss      | -20.9    |
# |    critic_loss     | 0.0344   |
# |    ent_coef        | 0.0599   |
# |    ent_coef_loss   | -16.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 104      |
# |    time_elapsed    | 195      |
# |    total_timesteps | 20400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 105      |
# |    time_elapsed    | 195      |
# |    total_timesteps | 20600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 106      |
# |    time_elapsed    | 196      |
# |    total_timesteps | 20800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 106      |
# |    time_elapsed    | 196      |
# |    total_timesteps | 21000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 99       |
# |    time_elapsed    | 212      |
# |    total_timesteps | 21200    |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 0.0365   |
# |    ent_coef        | 0.0449   |
# |    ent_coef_loss   | -17.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 100      |
# |    time_elapsed    | 213      |
# |    total_timesteps | 21400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 101      |
# |    time_elapsed    | 213      |
# |    total_timesteps | 21600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 101      |
# |    time_elapsed    | 213      |
# |    total_timesteps | 21800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 102      |
# |    time_elapsed    | 214      |
# |    total_timesteps | 22000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 444      |
# |    fps             | 96       |
# |    time_elapsed    | 230      |
# |    total_timesteps | 22200    |
# | train/             |          |
# |    actor_loss      | -18.7    |
# |    critic_loss     | 0.0395   |
# |    ent_coef        | 0.0337   |
# |    ent_coef_loss   | -18.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 448      |
# |    fps             | 97       |
# |    time_elapsed    | 230      |
# |    total_timesteps | 22400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 452      |
# |    fps             | 97       |
# |    time_elapsed    | 230      |
# |    total_timesteps | 22600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 456      |
# |    fps             | 98       |
# |    time_elapsed    | 231      |
# |    total_timesteps | 22800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 99       |
# |    time_elapsed    | 231      |
# |    total_timesteps | 23000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 464      |
# |    fps             | 93       |
# |    time_elapsed    | 248      |
# |    total_timesteps | 23200    |
# | train/             |          |
# |    actor_loss      | -17.4    |
# |    critic_loss     | 0.0442   |
# |    ent_coef        | 0.0253   |
# |    ent_coef_loss   | -18.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 468      |
# |    fps             | 94       |
# |    time_elapsed    | 248      |
# |    total_timesteps | 23400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 472      |
# |    fps             | 94       |
# |    time_elapsed    | 248      |
# |    total_timesteps | 23600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 476      |
# |    fps             | 95       |
# |    time_elapsed    | 249      |
# |    total_timesteps | 23800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 96       |
# |    time_elapsed    | 249      |
# |    total_timesteps | 24000    |
# ---------------------------------
# ...
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 1764     |
# |    fps             | 59       |
# |    time_elapsed    | 1481     |
# |    total_timesteps | 88200    |
# | train/             |          |
# |    actor_loss      | 7.21     |
# |    critic_loss     | 0.191    |
# |    ent_coef        | 0.00865  |
# |    ent_coef_loss   | 2.46     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 78000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 1768     |
# |    fps             | 59       |
# |    time_elapsed    | 1481     |
# |    total_timesteps | 88400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 1772     |
# |    fps             | 59       |
# |    time_elapsed    | 1481     |
# |    total_timesteps | 88600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 1776     |
# |    fps             | 59       |
# |    time_elapsed    | 1482     |
# |    total_timesteps | 88800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49      |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 1780     |
# |    fps             | 60       |
# |    time_elapsed    | 1482     |
# |    total_timesteps | 89000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 1784     |
# |    fps             | 59       |
# |    time_elapsed    | 1502     |
# |    total_timesteps | 89200    |
# | train/             |          |
# |    actor_loss      | 7.32     |
# |    critic_loss     | 0.199    |
# |    ent_coef        | 0.00923  |
# |    ent_coef_loss   | 0.632    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1788     |
# |    fps             | 59       |
# |    time_elapsed    | 1502     |
# |    total_timesteps | 89400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1792     |
# |    fps             | 59       |
# |    time_elapsed    | 1502     |
# |    total_timesteps | 89600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1796     |
# |    fps             | 59       |
# |    time_elapsed    | 1503     |
# |    total_timesteps | 89800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 59       |
# |    time_elapsed    | 1503     |
# |    total_timesteps | 90000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1804     |
# |    fps             | 59       |
# |    time_elapsed    | 1521     |
# |    total_timesteps | 90200    |
# | train/             |          |
# |    actor_loss      | 7.37     |
# |    critic_loss     | 0.205    |
# |    ent_coef        | 0.00924  |
# |    ent_coef_loss   | -2.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 80000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1808     |
# |    fps             | 59       |
# |    time_elapsed    | 1522     |
# |    total_timesteps | 90400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1812     |
# |    fps             | 59       |
# |    time_elapsed    | 1522     |
# |    total_timesteps | 90600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1816     |
# |    fps             | 59       |
# |    time_elapsed    | 1522     |
# |    total_timesteps | 90800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1820     |
# |    fps             | 59       |
# |    time_elapsed    | 1522     |
# |    total_timesteps | 91000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1824     |
# |    fps             | 59       |
# |    time_elapsed    | 1541     |
# |    total_timesteps | 91200    |
# | train/             |          |
# |    actor_loss      | 7.51     |
# |    critic_loss     | 0.206    |
# |    ent_coef        | 0.00891  |
# |    ent_coef_loss   | 0.877    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 81000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1828     |
# |    fps             | 59       |
# |    time_elapsed    | 1541     |
# |    total_timesteps | 91400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -47.5    |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 1832     |
# |    fps             | 59       |
# |    time_elapsed    | 1541     |
# |    total_timesteps | 91600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1836     |
# |    fps             | 59       |
# |    time_elapsed    | 1541     |
# |    total_timesteps | 91800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1840     |
# |    fps             | 59       |
# |    time_elapsed    | 1542     |
# |    total_timesteps | 92000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1844     |
# |    fps             | 59       |
# |    time_elapsed    | 1559     |
# |    total_timesteps | 92200    |
# | train/             |          |
# |    actor_loss      | 7.53     |
# |    critic_loss     | 0.194    |
# |    ent_coef        | 0.0092   |
# |    ent_coef_loss   | 0.511    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 82000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1848     |
# |    fps             | 59       |
# |    time_elapsed    | 1559     |
# |    total_timesteps | 92400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48      |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 1852     |
# |    fps             | 59       |
# |    time_elapsed    | 1560     |
# |    total_timesteps | 92600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 1856     |
# |    fps             | 59       |
# |    time_elapsed    | 1560     |
# |    total_timesteps | 92800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 1860     |
# |    fps             | 59       |
# |    time_elapsed    | 1560     |
# |    total_timesteps | 93000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 1864     |
# |    fps             | 59       |
# |    time_elapsed    | 1579     |
# |    total_timesteps | 93200    |
# | train/             |          |
# |    actor_loss      | 7.62     |
# |    critic_loss     | 0.216    |
# |    ent_coef        | 0.00872  |
# |    ent_coef_loss   | -2       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 83000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 1868     |
# |    fps             | 59       |
# |    time_elapsed    | 1579     |
# |    total_timesteps | 93400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 1872     |
# |    fps             | 59       |
# |    time_elapsed    | 1580     |
# |    total_timesteps | 93600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 1876     |
# |    fps             | 59       |
# |    time_elapsed    | 1580     |
# |    total_timesteps | 93800    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -48.5    |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 1880     |
# |    fps             | 59       |
# |    time_elapsed    | 1580     |
# |    total_timesteps | 94000    |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 model.learn(total_timesteps=500000)
#
# File ~/miniconda3/envs/dl2/lib/python3.11/site-packages/sb3_contrib/tqc/tqc.py:302, in TQC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     293 def learn(
#     294     self: SelfTQC,
#     295     total_timesteps: int,
#    (...)
#     300     progress_bar: bool = False,
#     301 ) -> SelfTQC:
# --> 302     return super().learn(
#     303         total_timesteps=total_timesteps,
#     304         callback=callback,
#     305         log_interval=log_interval,
#     306         tb_log_name=tb_log_name,
#     307         reset_num_timesteps=reset_num_timesteps,
#     308         progress_bar=progress_bar,
#     309     )
#
# File ~/miniconda3/envs/dl2/lib/python3.11/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~/miniconda3/envs/dl2/lib/python3.11/site-packages/sb3_contrib/tqc/tqc.py:275, in TQC.train(self, gradient_steps, batch_size)
#     273 # Optimize the actor
#     274 self.actor.optimizer.zero_grad()
# --> 275 actor_loss.backward()
#     276 self.actor.optimizer.step()
#     278 # Update target networks
#
# File ~/miniconda3/envs/dl2/lib/python3.11/site-packages/torch/_tensor.py:525, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     515 if has_torch_function_unary(self):
#     516     return handle_torch_function(
#     517         Tensor.backward,
#     518         (self,),
#    (...)
#     523         inputs=inputs,
#     524     )
# --> 525 torch.autograd.backward(
#     526     self, gradient, retain_graph, create_graph, inputs=inputs
#     527 )
#
# File ~/miniconda3/envs/dl2/lib/python3.11/site-packages/torch/autograd/__init__.py:267, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     262     retain_graph = create_graph
#     264 # The reason we repeat the same comment below is that
#     265 # some Python versions print out the first line of a multi-line function
#     266 # calls in the traceback and some print out the last line
# --> 267 _engine_run_backward(
#     268     tensors,
#     269     grad_tensors_,
#     270     retain_graph,
#     271     create_graph,
#     272     inputs,
#     273     allow_unreachable=True,
#     274     accumulate_grad=True,
#     275 )
#
# File ~/miniconda3/envs/dl2/lib/python3.11/site-packages/torch/autograd/graph.py:744, in _engine_run_backward(t_outputs, *args, **kwargs)
#     742     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743 try:
# --> 744     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745         t_outputs, *args, **kwargs
#     746     )  # Calls into the C++ engine to run the backward pass
#     747 finally:
#     748     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
import gymnasium as gym
import psutil
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv

# Define a function to create the environment
def make_env(env_id, rank, seed=0):
    def _init():
        env = gym.make(env_id)
        # Check if the environment has a `seed` method
        if hasattr(env.unwrapped, 'seed'):
            env.unwrapped.seed(seed + rank)
        return env
    return _init

def check_resources():
    # Check CPU and memory usage
    cpu_usage = psutil.cpu_percent(interval=1)
    memory_info = psutil.virtual_memory()
    return cpu_usage, memory_info

def test_parallel_envs(env_id, max_envs):
    for num_envs in range(1, max_envs + 1):
        try:
            print(f"Testing with {num_envs} parallel environments...")
            envs = SubprocVecEnv([make_env(env_id, i) for i in range(num_envs)])
            model = DDPG(
                'MultiInputPolicy',
                envs,
                replay_buffer_class=HerReplayBuffer,
                replay_buffer_kwargs=dict(
                    n_sampled_goal=4,
                    goal_selection_strategy="future"
                ),
                action_noise=action_noise,
                learning_rate=1e-3,
                batch_size=1024,
                buffer_size=1000000,
                learning_starts=10000,
                train_freq=1000,
                gamma=0.95,
                tau=0.05,
                verbose=1
            )
            model.learn(total_timesteps=1000)

            # Check resources after running the environments
            cpu_usage, memory_info = check_resources()
            print(f"CPU usage: {cpu_usage}%")
            print(f"Memory usage: {memory_info.percent}%")
            
            envs.close()

            if memory_info.percent > 90:  # Memory usage threshold
                print("Memory usage too high. Stopping the test.")
                break
        except Exception as e:
            print(f"Failed with {num_envs} environments: {e}")
            break

env_id = 'FetchPickAndPlace-v2'
max_envs = 20  # Adjust based on your initial estimation
test_parallel_envs(env_id, max_envs)
# Out:
# Testing with 1 parallel environments...
# Process ForkServerProcess-480:
# Process ForkServerProcess-510:
# Process ForkServerProcess-466:
# Process ForkServerProcess-473:
# Process ForkServerProcess-503:
# Process ForkServerProcess-476:
# Process ForkServerProcess-474:
# Process ForkServerProcess-467:
# Process ForkServerProcess-505:
# Process ForkServerProcess-464:
# Process ForkServerProcess-479:
# Process ForkServerProcess-497:
# Process ForkServerProcess-504:
# Process ForkServerProcess-495:
# Process ForkServerProcess-472:
# Process ForkServerProcess-506:
# Process ForkServerProcess-468:
# Process ForkServerProcess-502:
# Process ForkServerProcess-509:
# Process ForkServerProcess-477:
# Process ForkServerProcess-513:
# Process ForkServerProcess-514:
# Process ForkServerProcess-481:
# Process ForkServerProcess-515:
# Process ForkServerProcess-470:
# Process ForkServerProcess-463:
# Process ForkServerProcess-508:
# Process ForkServerProcess-486:
# Process ForkServerProcess-507:
# Process ForkServerProcess-498:
# Process ForkServerProcess-499:
# Process ForkServerProcess-512:
# Process ForkServerProcess-511:
# Process ForkServerProcess-500:
# Process ForkServerProcess-520:
# Process ForkServerProcess-462:
# Process ForkServerProcess-475:
# Process ForkServerProcess-521:
# Process ForkServerProcess-517:
# Process ForkServerProcess-496:
# Process ForkServerProcess-469:
# Process ForkServerProcess-478:
# Process ForkServerProcess-485:
# Process ForkServerProcess-488:
# Process ForkServerProcess-491:
# Process ForkServerProcess-501:
# Process ForkServerProcess-518:
# Process ForkServerProcess-489:
# Process ForkServerProcess-516:
# Process ForkServerProcess-519:
# Process ForkServerProcess-493:
# Process ForkServerProcess-492:
# Process ForkServerProcess-471:
# Process ForkServerProcess-465:
# Process ForkServerProcess-494:
# Process ForkServerProcess-484:
# Process ForkServerProcess-483:
# Process ForkServerProcess-487:
# Process ForkServerProcess-490:
# Process ForkServerProcess-522:
# Traceback (most recent call last):
#   File "/Users/photosartd/miniconda3/envs/dl2/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/photosartd/miniconda3/envs/dl2/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/photosartd/miniconda3/envs/dl2/lib/python3.11/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 29, in _worker
#     env = _patch_env(env_fn_wrapper.var())
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/9t/6ndcvv6d3fxbgyys2c6jh1rc0000gn/T/ipykernel_22657/382728829.py", line 9, in _init
#   File "/Users/photosartd/miniconda3/envs/dl2/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 802, in make
#     env = env_creator(**env_spec_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/photosartd/miniconda3/envs/dl2/lib/python3.11/site-packages/gymnasium_robotics/envs/fetch/pick_and_place.py", line 138, in __init__
#     MujocoFetchEnv.__init__(
#   File "/Users/photosartd/miniconda3/envs/dl2/lib/python3.11/site-packages/gymnasium_robotics/envs/fetch/fetch_env.py", line 293, in __init__
#     super().__init__(default_camera_config=default_camera_config, **kwargs)
#   File "/Users/photosartd/miniconda3/envs/dl2/lib/python3.11/site-packages/gymnasium_robotics/envs/fetch/fetch_env.py", line 69, in __init__
#     super().__init__(n_actions=4, **kwargs)
#   File "/Users/photosartd/miniconda3/envs/dl2/lib/python3.11/site-packages/gymnasium_robotics/envs/robot_env.py", line 280, in __init__
#     super().__init__(**kwargs)
#   File "/Users/photosartd/miniconda3/envs/dl2/lib/python3.11/site-packages/gymnasium_robotics/envs/robot_env.py", line 78, in __init__
#     self._initialize_simulation()
#   File "/Users/photosartd/miniconda3/envs/dl2/lib/python3.11/site-packages/gymnasium_robotics/envs/robot_env.py", line 289, in _initialize_simulation
#     self.model = self._mujoco.MjModel.from_xml_path(self.fullpath)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 63
#      61 env_id = 'FetchPickAndPlace-v2'
#      62 max_envs = 20  # Adjust based on your initial estimation
# ---> 63 test_parallel_envs(env_id, max_envs)
#
# Cell In[48], line 26, in test_parallel_envs(env_id, max_envs)
#      24 try:
#      25     print(f"Testing with {num_envs} parallel environments...")
# ---> 26     envs = SubprocVecEnv([make_env(env_id, i) for i in range(num_envs)])
#      27     model = DDPG(
#      28         'MultiInputPolicy',
#      29         envs,
#    (...)
#      43         verbose=1
#      44     )
#      45     model.learn(total_timesteps=1000)
#
# File ~/miniconda3/envs/dl2/lib/python3.11/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py:119, in SubprocVecEnv.__init__(self, env_fns, start_method)
#     116     work_remote.close()
#     118 self.remotes[0].send(("get_spaces", None))
# --> 119 observation_space, action_space = self.remotes[0].recv()
#     121 super().__init__(len(env_fns), observation_space, action_space)
#
# File ~/miniconda3/envs/dl2/lib/python3.11/multiprocessing/connection.py:250, in _ConnectionBase.recv(self)
#     248 self._check_closed()
#     249 self._check_readable()
# --> 250 buf = self._recv_bytes()
#     251 return _ForkingPickler.loads(buf.getbuffer())
#
# File ~/miniconda3/envs/dl2/lib/python3.11/multiprocessing/connection.py:430, in Connection._recv_bytes(self, maxsize)
#     429 def _recv_bytes(self, maxsize=None):
# --> 430     buf = self._recv(4)
#     431     size, = struct.unpack("!i", buf.getvalue())
#     432     if size == -1:
#
# File ~/miniconda3/envs/dl2/lib/python3.11/multiprocessing/connection.py:395, in Connection._recv(self, size, read)
#     393 remaining = size
#     394 while remaining > 0:
# --> 395     chunk = read(handle, remaining)
#     396     n = len(chunk)
#     397     if n == 0:
#
# KeyboardInterrupt:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):

# %% [markdown]
# ## Parallel training

# %%
#n_actions = 4
#action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

# %%
def linear_schedule(initial_value: float):
    """
    Linear learning rate schedule.

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return progress_remaining * initial_value

    return func

# %%
def make_env(env_id, rank, seed=0):
    def _init():
        env = gym.make(env_id, max_episode_steps=100)
        # Check if the environment has a `seed` method
        if hasattr(env.unwrapped, 'seed'):
            env.unwrapped.seed(seed + rank)
        return env
    return _init

# %%
env_id = 'FetchPickAndPlace-v2'
num_envs = 20  # Number of parallel environments

# %%
#envs = SubprocVecEnv([make_env(env_id, i) for i in range(num_envs)])
envs = DummyVecEnv([make_env(env_id, i) for i in range(num_envs)])

# %%
eval_env = DummyVecEnv([make_env(env_id, 20)])

# %%
model = TQC(
                'MultiInputPolicy',
                envs,
                replay_buffer_class=HerReplayBuffer,
                replay_buffer_kwargs=dict(
                    n_sampled_goal=4,
                    goal_selection_strategy="future"
                ),
                learning_rate=linear_schedule(0.001),
                batch_size=512,
                buffer_size=1000000,
                learning_starts=2100,
                train_freq=1,
                gradient_steps=-1,
                gamma=0.98,
                tau=0.005,
                policy_kwargs=dict(n_critics=2, net_arch=[128, 256, 64]),
                verbose=1,
            )
# Out:
# Using cuda device

# %%
eval_callback = EvalCallback(eval_env, 
                             best_model_save_path='./logs/',
                             log_path='./logs/', 
                             eval_freq=10000,
                             deterministic=True, 
                             render=False)

# %%
model.learn(total_timesteps=1000000, callback=eval_callback)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 483      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 483      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 483      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 483      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.1      |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 483      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2000     |
# ---------------------------------
# /homes/dtrofimov/miniconda3/envs/dl/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.compute_reward to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.compute_reward` for environment variables or `env.get_wrapper_attr('compute_reward')` that will search the reminding wrappers.
#   logger.warn(
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 104      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -6.86    |
# |    critic_loss     | 0.0177   |
# |    ent_coef        | 0.156    |
# |    ent_coef_loss   | -12.3    |
# |    learning_rate   | 0.000996 |
# |    n_updates       | 1880     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 104      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 4000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 104      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 4000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 104      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 4000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.05     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 104      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 4000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.0333   |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 84       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -5.14    |
# |    critic_loss     | 0.0179   |
# |    ent_coef        | 0.0246   |
# |    ent_coef_loss   | -17.4    |
# |    learning_rate   | 0.000994 |
# |    n_updates       | 3880     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.0333   |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 84       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 6000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.0333   |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 84       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 6000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.0333   |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 84       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 6000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.0333   |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 84       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 6000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.025    |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 77       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -3.22    |
# |    critic_loss     | 0.0248   |
# |    ent_coef        | 0.00557  |
# |    ent_coef_loss   | -18      |
# |    learning_rate   | 0.000992 |
# |    n_updates       | 5880     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.025    |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 77       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 8000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.025    |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 77       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 8000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.025    |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 77       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 8000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.025    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 77       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 8000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 72       |
# |    time_elapsed    | 137      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -1.21    |
# |    critic_loss     | 0.0427   |
# |    ent_coef        | 0.00254  |
# |    ent_coef_loss   | -20.4    |
# |    learning_rate   | 0.00099  |
# |    n_updates       | 7880     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 72       |
# |    time_elapsed    | 137      |
# |    total_timesteps | 10000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 72       |
# |    time_elapsed    | 137      |
# |    total_timesteps | 10000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 72       |
# |    time_elapsed    | 137      |
# |    total_timesteps | 10000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 72       |
# |    time_elapsed    | 137      |
# |    total_timesteps | 10000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 70       |
# |    time_elapsed    | 170      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | 0.447    |
# |    critic_loss     | 0.0244   |
# |    ent_coef        | 0.0024   |
# |    ent_coef_loss   | 1.77     |
# |    learning_rate   | 0.000988 |
# |    n_updates       | 9880     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 70       |
# |    time_elapsed    | 170      |
# |    total_timesteps | 12000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 70       |
# |    time_elapsed    | 170      |
# |    total_timesteps | 12000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 70       |
# |    time_elapsed    | 170      |
# |    total_timesteps | 12000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 70       |
# |    time_elapsed    | 170      |
# |    total_timesteps | 12000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 68       |
# |    time_elapsed    | 203      |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | 1.61     |
# |    critic_loss     | 0.0388   |
# |    ent_coef        | 0.002    |
# |    ent_coef_loss   | -7.27    |
# |    learning_rate   | 0.000986 |
# |    n_updates       | 11880    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 68       |
# |    time_elapsed    | 203      |
# |    total_timesteps | 14000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 68       |
# |    time_elapsed    | 203      |
# |    total_timesteps | 14000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 68       |
# |    time_elapsed    | 203      |
# |    total_timesteps | 14000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 68       |
# |    time_elapsed    | 203      |
# |    total_timesteps | 14000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 67       |
# |    time_elapsed    | 236      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | 2.75     |
# |    critic_loss     | 0.107    |
# |    ent_coef        | 0.00199  |
# |    ent_coef_loss   | -7.69    |
# |    learning_rate   | 0.000984 |
# |    n_updates       | 13880    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 67       |
# |    time_elapsed    | 237      |
# |    total_timesteps | 16000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 67       |
# |    time_elapsed    | 237      |
# |    total_timesteps | 16000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 67       |
# |    time_elapsed    | 237      |
# |    total_timesteps | 16000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 67       |
# |    time_elapsed    | 237      |
# |    total_timesteps | 16000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 488      |
# |    fps             | 20       |
# |    time_elapsed    | 2442     |
# |    total_timesteps | 50000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 492      |
# |    fps             | 20       |
# |    time_elapsed    | 2442     |
# |    total_timesteps | 50000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 496      |
# |    fps             | 20       |
# |    time_elapsed    | 2442     |
# |    total_timesteps | 50000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 20       |
# |    time_elapsed    | 2442     |
# |    total_timesteps | 50000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0.02      |
# | time/              |           |
# |    episodes        | 504       |
# |    fps             | 20        |
# |    time_elapsed    | 2552      |
# |    total_timesteps | 52000     |
# | train/             |           |
# |    actor_loss      | -3.41e+03 |
# |    critic_loss     | 139       |
# |    ent_coef        | 3.67      |
# |    ent_coef_loss   | -0.191    |
# |    learning_rate   | 0.000948  |
# |    n_updates       | 49880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 508      |
# |    fps             | 20       |
# |    time_elapsed    | 2552     |
# |    total_timesteps | 52000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 512      |
# |    fps             | 20       |
# |    time_elapsed    | 2552     |
# |    total_timesteps | 52000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 516      |
# |    fps             | 20       |
# |    time_elapsed    | 2552     |
# |    total_timesteps | 52000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 20       |
# |    time_elapsed    | 2552     |
# |    total_timesteps | 52000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0.02      |
# | time/              |           |
# |    episodes        | 524       |
# |    fps             | 20        |
# |    time_elapsed    | 2664      |
# |    total_timesteps | 54000     |
# | train/             |           |
# |    actor_loss      | -3.83e+03 |
# |    critic_loss     | 156       |
# |    ent_coef        | 4.17      |
# |    ent_coef_loss   | -0.244    |
# |    learning_rate   | 0.000946  |
# |    n_updates       | 51880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 528      |
# |    fps             | 20       |
# |    time_elapsed    | 2664     |
# |    total_timesteps | 54000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 532      |
# |    fps             | 20       |
# |    time_elapsed    | 2664     |
# |    total_timesteps | 54000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 536      |
# |    fps             | 20       |
# |    time_elapsed    | 2664     |
# |    total_timesteps | 54000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 20       |
# |    time_elapsed    | 2664     |
# |    total_timesteps | 54000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0.02      |
# | time/              |           |
# |    episodes        | 544       |
# |    fps             | 20        |
# |    time_elapsed    | 2777      |
# |    total_timesteps | 56000     |
# | train/             |           |
# |    actor_loss      | -4.44e+03 |
# |    critic_loss     | 193       |
# |    ent_coef        | 5.15      |
# |    ent_coef_loss   | -0.113    |
# |    learning_rate   | 0.000944  |
# |    n_updates       | 53880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 548      |
# |    fps             | 20       |
# |    time_elapsed    | 2777     |
# |    total_timesteps | 56000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 552      |
# |    fps             | 20       |
# |    time_elapsed    | 2777     |
# |    total_timesteps | 56000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 556      |
# |    fps             | 20       |
# |    time_elapsed    | 2777     |
# |    total_timesteps | 56000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 20       |
# |    time_elapsed    | 2777     |
# |    total_timesteps | 56000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0.01      |
# | time/              |           |
# |    episodes        | 564       |
# |    fps             | 20        |
# |    time_elapsed    | 2888      |
# |    total_timesteps | 58000     |
# | train/             |           |
# |    actor_loss      | -5.05e+03 |
# |    critic_loss     | 216       |
# |    ent_coef        | 5.24      |
# |    ent_coef_loss   | 0.256     |
# |    learning_rate   | 0.000942  |
# |    n_updates       | 55880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 568      |
# |    fps             | 20       |
# |    time_elapsed    | 2888     |
# |    total_timesteps | 58000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 572      |
# |    fps             | 20       |
# |    time_elapsed    | 2888     |
# |    total_timesteps | 58000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 576      |
# |    fps             | 20       |
# |    time_elapsed    | 2888     |
# |    total_timesteps | 58000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 580      |
# |    fps             | 20       |
# |    time_elapsed    | 2888     |
# |    total_timesteps | 58000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0.01      |
# | time/              |           |
# |    episodes        | 584       |
# |    fps             | 19        |
# |    time_elapsed    | 3001      |
# |    total_timesteps | 60000     |
# | train/             |           |
# |    actor_loss      | -5.67e+03 |
# |    critic_loss     | 239       |
# |    ent_coef        | 6.03      |
# |    ent_coef_loss   | 0.0949    |
# |    learning_rate   | 0.00094   |
# |    n_updates       | 57880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 588      |
# |    fps             | 19       |
# |    time_elapsed    | 3001     |
# |    total_timesteps | 60000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 592      |
# |    fps             | 19       |
# |    time_elapsed    | 3001     |
# |    total_timesteps | 60000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 596      |
# |    fps             | 19       |
# |    time_elapsed    | 3001     |
# |    total_timesteps | 60000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 19       |
# |    time_elapsed    | 3001     |
# |    total_timesteps | 60000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0         |
# | time/              |           |
# |    episodes        | 604       |
# |    fps             | 19        |
# |    time_elapsed    | 3119      |
# |    total_timesteps | 62000     |
# | train/             |           |
# |    actor_loss      | -6.76e+03 |
# |    critic_loss     | 298       |
# |    ent_coef        | 7.78      |
# |    ent_coef_loss   | -0.614    |
# |    learning_rate   | 0.000938  |
# |    n_updates       | 59880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 608      |
# |    fps             | 19       |
# |    time_elapsed    | 3119     |
# |    total_timesteps | 62000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 612      |
# |    fps             | 19       |
# |    time_elapsed    | 3119     |
# |    total_timesteps | 62000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 616      |
# |    fps             | 19       |
# |    time_elapsed    | 3119     |
# |    total_timesteps | 62000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 620      |
# |    fps             | 19       |
# |    time_elapsed    | 3119     |
# |    total_timesteps | 62000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0         |
# | time/              |           |
# |    episodes        | 624       |
# |    fps             | 19        |
# |    time_elapsed    | 3230      |
# |    total_timesteps | 64000     |
# | train/             |           |
# |    actor_loss      | -8.07e+03 |
# |    critic_loss     | 368       |
# |    ent_coef        | 8.64      |
# |    ent_coef_loss   | -0.125    |
# |    learning_rate   | 0.000936  |
# |    n_updates       | 61880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 628      |
# |    fps             | 19       |
# |    time_elapsed    | 3230     |
# |    total_timesteps | 64000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 632      |
# |    fps             | 19       |
# |    time_elapsed    | 3230     |
# |    total_timesteps | 64000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 636      |
# |    fps             | 19       |
# |    time_elapsed    | 3230     |
# |    total_timesteps | 64000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 640      |
# |    fps             | 19       |
# |    time_elapsed    | 3230     |
# |    total_timesteps | 64000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0         |
# | time/              |           |
# |    episodes        | 644       |
# |    fps             | 19        |
# |    time_elapsed    | 3348      |
# |    total_timesteps | 66000     |
# | train/             |           |
# |    actor_loss      | -9.06e+03 |
# |    critic_loss     | 409       |
# |    ent_coef        | 10.5      |
# |    ent_coef_loss   | -0.00116  |
# |    learning_rate   | 0.000934  |
# |    n_updates       | 63880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 648      |
# |    fps             | 19       |
# |    time_elapsed    | 3348     |
# |    total_timesteps | 66000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 652      |
# |    fps             | 19       |
# |    time_elapsed    | 3348     |
# |    total_timesteps | 66000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 656      |
# |    fps             | 19       |
# |    time_elapsed    | 3348     |
# |    total_timesteps | 66000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 660      |
# |    fps             | 19       |
# |    time_elapsed    | 3348     |
# |    total_timesteps | 66000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0         |
# | time/              |           |
# |    episodes        | 664       |
# |    fps             | 19        |
# |    time_elapsed    | 3460      |
# |    total_timesteps | 68000     |
# | train/             |           |
# |    actor_loss      | -1.02e+04 |
# |    critic_loss     | 481       |
# |    ent_coef        | 10.4      |
# |    ent_coef_loss   | -0.335    |
# |    learning_rate   | 0.000932  |
# |    n_updates       | 65880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 668      |
# |    fps             | 19       |
# |    time_elapsed    | 3460     |
# |    total_timesteps | 68000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 672      |
# |    fps             | 19       |
# |    time_elapsed    | 3460     |
# |    total_timesteps | 68000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 676      |
# |    fps             | 19       |
# |    time_elapsed    | 3460     |
# |    total_timesteps | 68000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 680      |
# |    fps             | 19       |
# |    time_elapsed    | 3460     |
# |    total_timesteps | 68000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0.02      |
# | time/              |           |
# |    episodes        | 684       |
# |    fps             | 19        |
# |    time_elapsed    | 3575      |
# |    total_timesteps | 70000     |
# | train/             |           |
# |    actor_loss      | -1.13e+04 |
# |    critic_loss     | 542       |
# |    ent_coef        | 10.9      |
# |    ent_coef_loss   | 0.588     |
# |    learning_rate   | 0.00093   |
# |    n_updates       | 67880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 688      |
# |    fps             | 19       |
# |    time_elapsed    | 3575     |
# |    total_timesteps | 70000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 692      |
# |    fps             | 19       |
# |    time_elapsed    | 3575     |
# |    total_timesteps | 70000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 696      |
# |    fps             | 19       |
# |    time_elapsed    | 3575     |
# |    total_timesteps | 70000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 19       |
# |    time_elapsed    | 3575     |
# |    total_timesteps | 70000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0.03      |
# | time/              |           |
# |    episodes        | 704       |
# |    fps             | 19        |
# |    time_elapsed    | 3686      |
# |    total_timesteps | 72000     |
# | train/             |           |
# |    actor_loss      | -1.33e+04 |
# |    critic_loss     | 658       |
# |    ent_coef        | 10.9      |
# |    ent_coef_loss   | 0.0752    |
# |    learning_rate   | 0.000928  |
# |    n_updates       | 69880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 708      |
# |    fps             | 19       |
# |    time_elapsed    | 3686     |
# |    total_timesteps | 72000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 712      |
# |    fps             | 19       |
# |    time_elapsed    | 3686     |
# |    total_timesteps | 72000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 716      |
# |    fps             | 19       |
# |    time_elapsed    | 3686     |
# |    total_timesteps | 72000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.03     |
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 19       |
# |    time_elapsed    | 3686     |
# |    total_timesteps | 72000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 724      |
# |    fps             | 19       |
# |    time_elapsed    | 3804     |
# |    total_timesteps | 74000    |
# | train/             |          |
# |    actor_loss      | -1.5e+04 |
# |    critic_loss     | 720      |
# |    ent_coef        | 14.6     |
# |    ent_coef_loss   | 0.153    |
# |    learning_rate   | 0.000926 |
# |    n_updates       | 71880    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 728      |
# |    fps             | 19       |
# |    time_elapsed    | 3804     |
# |    total_timesteps | 74000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 732      |
# |    fps             | 19       |
# |    time_elapsed    | 3804     |
# |    total_timesteps | 74000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 736      |
# |    fps             | 19       |
# |    time_elapsed    | 3804     |
# |    total_timesteps | 74000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 19       |
# |    time_elapsed    | 3804     |
# |    total_timesteps | 74000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0.04      |
# | time/              |           |
# |    episodes        | 744       |
# |    fps             | 19        |
# |    time_elapsed    | 3919      |
# |    total_timesteps | 76000     |
# | train/             |           |
# |    actor_loss      | -1.81e+04 |
# |    critic_loss     | 862       |
# |    ent_coef        | 18.2      |
# |    ent_coef_loss   | 0.542     |
# |    learning_rate   | 0.000924  |
# |    n_updates       | 73880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 748      |
# |    fps             | 19       |
# |    time_elapsed    | 3919     |
# |    total_timesteps | 76000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 752      |
# |    fps             | 19       |
# |    time_elapsed    | 3919     |
# |    total_timesteps | 76000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 756      |
# |    fps             | 19       |
# |    time_elapsed    | 3919     |
# |    total_timesteps | 76000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 19       |
# |    time_elapsed    | 3919     |
# |    total_timesteps | 76000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0.04      |
# | time/              |           |
# |    episodes        | 764       |
# |    fps             | 19        |
# |    time_elapsed    | 4029      |
# |    total_timesteps | 78000     |
# | train/             |           |
# |    actor_loss      | -2.01e+04 |
# |    critic_loss     | 958       |
# |    ent_coef        | 21.8      |
# |    ent_coef_loss   | 0.376     |
# |    learning_rate   | 0.000922  |
# |    n_updates       | 75880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 768      |
# |    fps             | 19       |
# |    time_elapsed    | 4029     |
# |    total_timesteps | 78000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 772      |
# |    fps             | 19       |
# |    time_elapsed    | 4029     |
# |    total_timesteps | 78000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 776      |
# |    fps             | 19       |
# |    time_elapsed    | 4029     |
# |    total_timesteps | 78000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.04     |
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 19       |
# |    time_elapsed    | 4029     |
# |    total_timesteps | 78000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 784      |
# |    fps             | 19       |
# |    time_elapsed    | 4142     |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -2.4e+04 |
# |    critic_loss     | 1.14e+03 |
# |    ent_coef        | 24.8     |
# |    ent_coef_loss   | 0.629    |
# |    learning_rate   | 0.00092  |
# |    n_updates       | 77880    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 788      |
# |    fps             | 19       |
# |    time_elapsed    | 4142     |
# |    total_timesteps | 80000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 792      |
# |    fps             | 19       |
# |    time_elapsed    | 4142     |
# |    total_timesteps | 80000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 796      |
# |    fps             | 19       |
# |    time_elapsed    | 4142     |
# |    total_timesteps | 80000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 19       |
# |    time_elapsed    | 4142     |
# |    total_timesteps | 80000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0.01      |
# | time/              |           |
# |    episodes        | 804       |
# |    fps             | 19        |
# |    time_elapsed    | 4253      |
# |    total_timesteps | 82000     |
# | train/             |           |
# |    actor_loss      | -2.81e+04 |
# |    critic_loss     | 1.28e+03  |
# |    ent_coef        | 30.6      |
# |    ent_coef_loss   | 0.424     |
# |    learning_rate   | 0.000918  |
# |    n_updates       | 79880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 808      |
# |    fps             | 19       |
# |    time_elapsed    | 4253     |
# |    total_timesteps | 82000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 812      |
# |    fps             | 19       |
# |    time_elapsed    | 4253     |
# |    total_timesteps | 82000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 816      |
# |    fps             | 19       |
# |    time_elapsed    | 4253     |
# |    total_timesteps | 82000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 820      |
# |    fps             | 19       |
# |    time_elapsed    | 4253     |
# |    total_timesteps | 82000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0.01      |
# | time/              |           |
# |    episodes        | 824       |
# |    fps             | 19        |
# |    time_elapsed    | 4364      |
# |    total_timesteps | 84000     |
# | train/             |           |
# |    actor_loss      | -3.38e+04 |
# |    critic_loss     | 1.51e+03  |
# |    ent_coef        | 32.3      |
# |    ent_coef_loss   | -0.000481 |
# |    learning_rate   | 0.000916  |
# |    n_updates       | 81880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 828      |
# |    fps             | 19       |
# |    time_elapsed    | 4364     |
# |    total_timesteps | 84000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 832      |
# |    fps             | 19       |
# |    time_elapsed    | 4364     |
# |    total_timesteps | 84000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 836      |
# |    fps             | 19       |
# |    time_elapsed    | 4364     |
# |    total_timesteps | 84000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    episodes        | 840      |
# |    fps             | 19       |
# |    time_elapsed    | 4364     |
# |    total_timesteps | 84000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0.02      |
# | time/              |           |
# |    episodes        | 844       |
# |    fps             | 19        |
# |    time_elapsed    | 4467      |
# |    total_timesteps | 86000     |
# | train/             |           |
# |    actor_loss      | -4.17e+04 |
# |    critic_loss     | 1.85e+03  |
# |    ent_coef        | 35.6      |
# |    ent_coef_loss   | 0.569     |
# |    learning_rate   | 0.000914  |
# |    n_updates       | 83880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 848      |
# |    fps             | 19       |
# |    time_elapsed    | 4467     |
# |    total_timesteps | 86000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 852      |
# |    fps             | 19       |
# |    time_elapsed    | 4467     |
# |    total_timesteps | 86000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 856      |
# |    fps             | 19       |
# |    time_elapsed    | 4467     |
# |    total_timesteps | 86000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 860      |
# |    fps             | 19       |
# |    time_elapsed    | 4467     |
# |    total_timesteps | 86000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0.02      |
# | time/              |           |
# |    episodes        | 864       |
# |    fps             | 19        |
# |    time_elapsed    | 4566      |
# |    total_timesteps | 88000     |
# | train/             |           |
# |    actor_loss      | -4.68e+04 |
# |    critic_loss     | 2.15e+03  |
# |    ent_coef        | 37.3      |
# |    ent_coef_loss   | 1.39      |
# |    learning_rate   | 0.000912  |
# |    n_updates       | 85880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 868      |
# |    fps             | 19       |
# |    time_elapsed    | 4566     |
# |    total_timesteps | 88000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 872      |
# |    fps             | 19       |
# |    time_elapsed    | 4566     |
# |    total_timesteps | 88000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 876      |
# |    fps             | 19       |
# |    time_elapsed    | 4566     |
# |    total_timesteps | 88000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 880      |
# |    fps             | 19       |
# |    time_elapsed    | 4566     |
# |    total_timesteps | 88000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    success_rate    | 0.02      |
# | time/              |           |
# |    episodes        | 884       |
# |    fps             | 19        |
# |    time_elapsed    | 4676      |
# |    total_timesteps | 90000     |
# | train/             |           |
# |    actor_loss      | -6.31e+04 |
# |    critic_loss     | 2.97e+03  |
# |    ent_coef        | 44.7      |
# |    ent_coef_loss   | -1.7      |
# |    learning_rate   | 0.00091   |
# |    n_updates       | 87880     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 888      |
# |    fps             | 19       |
# |    time_elapsed    | 4676     |
# |    total_timesteps | 90000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 892      |
# |    fps             | 19       |
# |    time_elapsed    | 4676     |
# |    total_timesteps | 90000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 896      |
# |    fps             | 19       |
# |    time_elapsed    | 4676     |
# |    total_timesteps | 90000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.02     |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 19       |
# |    time_elapsed    | 4676     |
# |    total_timesteps | 90000    |
# ---------------------------------

# %% [markdown]
# # Try 2

# %%
gym.__version__
# Out:
# '0.29.1'

# %%
registered_envs = set(gym.envs.registry.keys())

# %%
len(registered_envs)
# Out:
# 1200

# %%
[s for s in registered_envs if s.startswith("F")]
# Out:
# ['FreewayNoFrameskip-v4',
#  'FetchSlideDense-v2',
#  'FetchPickAndPlace-v2',
#  'FetchSlide-v2',
#  'FishingDerby-ramDeterministic-v0',
#  'Frostbite-ramNoFrameskip-v4',
#  'FrozenLake-v1',
#  'FetchPickAndPlaceDense-v1',
#  'Freeway-ramNoFrameskip-v4',
#  'FishingDerbyDeterministic-v0',
#  'Frostbite-ramDeterministic-v4',
#  'FetchSlideDense-v1',
#  'FetchReach-v1',
#  'FetchPushDense-v2',
#  'FetchPickAndPlace-v1',
#  'FetchPushDense-v1',
#  'FreewayDeterministic-v0',
#  'FishingDerbyNoFrameskip-v4',
#  'Freeway-ramDeterministic-v4',
#  'FishingDerbyDeterministic-v4',
#  'FetchSlide-v1',
#  'FishingDerby-ramDeterministic-v4',
#  'FishingDerby-ram-v4',
#  'Frostbite-ramDeterministic-v0',
#  'Freeway-v4',
#  'FishingDerbyNoFrameskip-v0',
#  'FishingDerby-ramNoFrameskip-v0',
#  'Freeway-ram-v0',
#  'FishingDerby-v0',
#  'FishingDerby-ram-v0',
#  'Freeway-ram-v4',
#  'FetchReachDense-v1',
#  'Freeway-ramDeterministic-v0',
#  'FishingDerby-ramNoFrameskip-v4',
#  'FetchPush-v2',
#  'FrostbiteDeterministic-v4',
#  'FrostbiteNoFrameskip-v0',
#  'FetchPickAndPlaceDense-v2',
#  'FishingDerby-v4',
#  'FetchReach-v2',
#  'FetchPush-v1',
#  'FrankaKitchen-v1',
#  'FrostbiteDeterministic-v0',
#  'Frostbite-ramNoFrameskip-v0',
#  'Frostbite-v0',
#  'FreewayNoFrameskip-v0',
#  'Frostbite-v4',
#  'FrozenLake8x8-v1',
#  'Frostbite-ram-v0',
#  'Freeway-ramNoFrameskip-v0',
#  'FreewayDeterministic-v4',
#  'FrostbiteNoFrameskip-v4',
#  'Frostbite-ram-v4',
#  'FetchReachDense-v2',
#  'Freeway-v0']
